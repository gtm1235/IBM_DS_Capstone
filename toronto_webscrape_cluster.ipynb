# %%
import pandas as pd

# %%
url = r'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %%
table_toronto = pd.read_html(url)
table_toronto = table_toronto[0]
table_toronto.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
pd_borough= table_toronto.loc[table_toronto['Borough'] != 'Not assigned',].reset_index()
pd_borough = pd_borough[['Postcode', 'Borough','Neighbourhood']]
pd_borough.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M3A        North York         Parkwoods
# 1      M4A        North York  Victoria Village
# 2      M5A  Downtown Toronto      Harbourfront
# 3      M5A  Downtown Toronto       Regent Park
# 4      M6A        North York  Lawrence Heights

# %%
df_by_pc = pd_borough.groupby('Postcode')
df_by_pc.head()
# Out:
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M5A  Downtown Toronto
# 4        M6A        North York
# 5        M6A        North York
# 6        M7A      Queen's Park
# 7        M9A         Etobicoke
# 8        M1B       Scarborough
# 9        M1B       Scarborough
# 10       M3B        North York
# 11       M4B         East York
# 12       M4B         East York
# 13       M5B  Downtown Toronto
# 14       M5B  Downtown Toronto
# 15       M6B        North York
# 16       M9B         Etobicoke
# 17       M9B         Etobicoke
# 18       M9B         Etobicoke
# 19       M9B         Etobicoke
# 20       M9B         Etobicoke
# 21       M1C       Scarborough
# 22       M1C       Scarborough
# 23       M1C       Scarborough
# 24       M3C        North York
# 25       M3C        North York
# 26       M4C         East York
# 27       M5C  Downtown Toronto
# 28       M6C              York
# 29       M9C         Etobicoke
# ..       ...               ...
# 175      M9V         Etobicoke
# 176      M9V         Etobicoke
# 177      M9V         Etobicoke
# 178      M9V         Etobicoke
# 182      M1W       Scarborough
# 183      M4W  Downtown Toronto
# 184      M5W  Downtown Toronto
# 185      M8W         Etobicoke
# 186      M8W         Etobicoke
# 187      M9W         Etobicoke
# 188      M1X       Scarborough
# 189      M4X  Downtown Toronto
# 190      M4X  Downtown Toronto
# 191      M5X  Downtown Toronto
# 192      M5X  Downtown Toronto
# 193      M8X         Etobicoke
# 194      M8X         Etobicoke
# 195      M8X         Etobicoke
# 196      M4Y  Downtown Toronto
# 197      M7Y      East Toronto
# 198      M8Y         Etobicoke
# 199      M8Y         Etobicoke
# 200      M8Y         Etobicoke
# 201      M8Y         Etobicoke
# 202      M8Y         Etobicoke
# 206      M8Z         Etobicoke
# 207      M8Z         Etobicoke
# 208      M8Z         Etobicoke
# 209      M8Z         Etobicoke
# 210      M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                                         Harbourfront
# 3                                          Regent Park
# 4                                     Lawrence Heights
# 5                                       Lawrence Manor
# 6                                         Not assigned
# 7                                     Islington Avenue
# 8                                                Rouge
# 9                                              Malvern
# 10                                     Don Mills North
# 11                                    Woodbine Gardens
# 12                                       Parkview Hill
# 13                                             Ryerson
# 14                                     Garden District
# 15                                           Glencairn
# 16                                          Cloverdale
# 17                                           Islington
# 18                                        Martin Grove
# 19                                    Princess Gardens
# 20                                     West Deane Park
# 21                                      Highland Creek
# 22                                          Rouge Hill
# 23                                          Port Union
# 24                                     Flemingdon Park
# 25                                     Don Mills South
# 26                                    Woodbine Heights
# 27                                      St. James Town
# 28                                  Humewood-Cedarvale
# 29                                   Bloordale Gardens
# ..                                                 ...
# 175                                   Beaumond Heights
# 176                                         Humbergate
# 177                                          Jamestown
# 178                                        Mount Olive
# 182                                    L'Amoreaux West
# 183                                           Rosedale
# 184                    Stn A PO Boxes 25 The Esplanade
# 185                                          Alderwood
# 186                                        Long Branch
# 187                                          Northwest
# 188                                        Upper Rouge
# 189                                        Cabbagetown
# 190                                     St. James Town
# 191                               First Canadian Place
# 192                                   Underground city
# 193                                       The Kingsway
# 194                                    Montgomery Road
# 195                                     Old Mill North
# 196                               Church and Wellesley
# 197  Business Reply Mail Processing Centre 969 Eastern
# 198                                         Humber Bay
# 199                                   King's Mill Park
# 200                           Kingsway Park South East
# 201                                          Mimico NE
# 202                                     Old Mill South
# 206                           Kingsway Park South West
# 207                                          Mimico NW
# 208                                 The Queensway West
# 209                              Royal York South West
# 210                                     South of Bloor
#
# [203 rows x 3 columns]

# %%
nb_df_combine = pd.DataFrame(columns = list(pd_borough.columns))
nb_df_combine
# Out:
# Empty DataFrame
# Columns: [Postcode, Borough, Neighbourhood]
# Index: []

# %%
temp_list = []
for i in range(len(df_by_pc['Postcode'].unique())):
    for nbh in list(df_by_pc)[i][1]['Neighbourhood']:
         temp_list.append(nbh)
         
        
    temp_list_1 = ', '.join(str(e) for e in temp_list)
    data = {'Neighbourhood': temp_list_1, 'Postcode':(list(df_by_pc)[i][1]['Postcode'].unique())[0],
           'Borough': pd_borough[pd_borough['Postcode']== (list(df_by_pc)[i][1]['Postcode'].unique())[0]]['Borough'].unique()[0]}
    nb_df_combine = nb_df_combine.append(data, ignore_index=True)
    temp_list = []
nb_df_combine
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# ..       ...               ...
# 176      M6C              York
# 177      M6E              York
# 178      M6G  Downtown Toronto
# 179      M6H      West Toronto
# 180      M6J      West Toronto
# 181      M6K      West Toronto
# 182      M6L        North York
# 183      M6M              York
# 184      M6N              York
# 185      M6P      West Toronto
# 186      M6R      West Toronto
# 187      M6S      West Toronto
# 188      M7A      Queen's Park
# 189      M7R       Mississauga
# 190      M7Y      East Toronto
# 191      M8V         Etobicoke
# 192      M8W         Etobicoke
# 193      M8X         Etobicoke
# 194      M8Y         Etobicoke
# 195      M8Z         Etobicoke
# 196      M9A         Etobicoke
# 197      M9B         Etobicoke
# 198      M9C         Etobicoke
# 199      M9L        North York
# 200      M9M        North York
# 201      M9N              York
# 202      M9P         Etobicoke
# 203      M9R         Etobicoke
# 204      M9V         Etobicoke
# 205      M9W         Etobicoke
#
#                                          Neighbourhood
# 0                                       Rouge, Malvern
# 1               Highland Creek, Rouge Hill, Port Union
# 2                    Guildwood, Morningside, West Hill
# 3                                               Woburn
# 4                                            Cedarbrae
# 5                                  Scarborough Village
# 6          East Birchmount Park, Ionview, Kennedy Park
# 7                      Clairlea, Golden Mile, Oakridge
# 8      Cliffcrest, Cliffside, Scarborough Village West
# 9                          Birch Cliff, Cliffside West
# 10   Dorset Park, Scarborough Town Centre, Wexford ...
# 11                                   Maryvale, Wexford
# 12                                           Agincourt
# 13             Clarks Corners, Sullivan, Tam O'Shanter
# 14   Agincourt North, L'Amoreaux East, Milliken, St...
# 15                                     L'Amoreaux West
# 16                                         Upper Rouge
# 17                                   Hillcrest Village
# 18                        Fairview, Henry Farm, Oriole
# 19                                     Bayview Village
# 20                            Silver Hills, York Mills
# 21                             Newtonbrook, Willowdale
# 22                                    Willowdale South
# 23                                     York Mills West
# 24                                     Willowdale West
# 25                                           Parkwoods
# 26                                     Don Mills North
# 27                    Flemingdon Park, Don Mills South
# 28     Bathurst Manor, Downsview North, Wilson Heights
# 29                     Northwood Park, York University
# ..                                                 ...
# 176                                 Humewood-Cedarvale
# 177                                Caledonia-Fairbanks
# 178                                           Christie
# 179                       Dovercourt Village, Dufferin
# 180                           Little Portugal, Trinity
# 181       Brockton, Exhibition Place, Parkdale Village
# 182                 Downsview, North Park, Upwood Park
# 183     Del Ray, Keelesdale, Mount Dennis, Silverthorn
# 184                      The Junction North, Runnymede
# 185                      High Park, The Junction South
# 186                             Parkdale, Roncesvalles
# 187                                 Runnymede, Swansea
# 188                                       Not assigned
# 189              Canada Post Gateway Processing Centre
# 190  Business Reply Mail Processing Centre 969 Eastern
# 191       Humber Bay Shores, Mimico South, New Toronto
# 192                             Alderwood, Long Branch
# 193      The Kingsway, Montgomery Road, Old Mill North
# 194  Humber Bay, King's Mill Park, Kingsway Park So...
# 195  Kingsway Park South West, Mimico NW, The Queen...
# 196                                   Islington Avenue
# 197  Cloverdale, Islington, Martin Grove, Princess ...
# 198  Bloordale Gardens, Eringate, Markland Wood, Ol...
# 199                                      Humber Summit
# 200                                   Emery, Humberlea
# 201                                             Weston
# 202                                          Westmount
# 203  Kingsview Village, Martin Grove Gardens, Richv...
# 204  Albion Gardens, Beaumond Heights, Humbergate, ...
# 205                                          Northwest
#
# [206 rows x 3 columns]

# %%
nb_df_combine.loc[nb_df_combine['Neighbourhood']=='Not assigned', ['Neighbourhood']] = nb_df_combine['Borough']
nb_df_combine
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# ..       ...               ...
# 176      M6C              York
# 177      M6E              York
# 178      M6G  Downtown Toronto
# 179      M6H      West Toronto
# 180      M6J      West Toronto
# 181      M6K      West Toronto
# 182      M6L        North York
# 183      M6M              York
# 184      M6N              York
# 185      M6P      West Toronto
# 186      M6R      West Toronto
# 187      M6S      West Toronto
# 188      M7A      Queen's Park
# 189      M7R       Mississauga
# 190      M7Y      East Toronto
# 191      M8V         Etobicoke
# 192      M8W         Etobicoke
# 193      M8X         Etobicoke
# 194      M8Y         Etobicoke
# 195      M8Z         Etobicoke
# 196      M9A         Etobicoke
# 197      M9B         Etobicoke
# 198      M9C         Etobicoke
# 199      M9L        North York
# 200      M9M        North York
# 201      M9N              York
# 202      M9P         Etobicoke
# 203      M9R         Etobicoke
# 204      M9V         Etobicoke
# 205      M9W         Etobicoke
#
#                                          Neighbourhood
# 0                                       Rouge, Malvern
# 1               Highland Creek, Rouge Hill, Port Union
# 2                    Guildwood, Morningside, West Hill
# 3                                               Woburn
# 4                                            Cedarbrae
# 5                                  Scarborough Village
# 6          East Birchmount Park, Ionview, Kennedy Park
# 7                      Clairlea, Golden Mile, Oakridge
# 8      Cliffcrest, Cliffside, Scarborough Village West
# 9                          Birch Cliff, Cliffside West
# 10   Dorset Park, Scarborough Town Centre, Wexford ...
# 11                                   Maryvale, Wexford
# 12                                           Agincourt
# 13             Clarks Corners, Sullivan, Tam O'Shanter
# 14   Agincourt North, L'Amoreaux East, Milliken, St...
# 15                                     L'Amoreaux West
# 16                                         Upper Rouge
# 17                                   Hillcrest Village
# 18                        Fairview, Henry Farm, Oriole
# 19                                     Bayview Village
# 20                            Silver Hills, York Mills
# 21                             Newtonbrook, Willowdale
# 22                                    Willowdale South
# 23                                     York Mills West
# 24                                     Willowdale West
# 25                                           Parkwoods
# 26                                     Don Mills North
# 27                    Flemingdon Park, Don Mills South
# 28     Bathurst Manor, Downsview North, Wilson Heights
# 29                     Northwood Park, York University
# ..                                                 ...
# 176                                 Humewood-Cedarvale
# 177                                Caledonia-Fairbanks
# 178                                           Christie
# 179                       Dovercourt Village, Dufferin
# 180                           Little Portugal, Trinity
# 181       Brockton, Exhibition Place, Parkdale Village
# 182                 Downsview, North Park, Upwood Park
# 183     Del Ray, Keelesdale, Mount Dennis, Silverthorn
# 184                      The Junction North, Runnymede
# 185                      High Park, The Junction South
# 186                             Parkdale, Roncesvalles
# 187                                 Runnymede, Swansea
# 188                                       Queen's Park
# 189              Canada Post Gateway Processing Centre
# 190  Business Reply Mail Processing Centre 969 Eastern
# 191       Humber Bay Shores, Mimico South, New Toronto
# 192                             Alderwood, Long Branch
# 193      The Kingsway, Montgomery Road, Old Mill North
# 194  Humber Bay, King's Mill Park, Kingsway Park So...
# 195  Kingsway Park South West, Mimico NW, The Queen...
# 196                                   Islington Avenue
# 197  Cloverdale, Islington, Martin Grove, Princess ...
# 198  Bloordale Gardens, Eringate, Markland Wood, Ol...
# 199                                      Humber Summit
# 200                                   Emery, Humberlea
# 201                                             Weston
# 202                                          Westmount
# 203  Kingsview Village, Martin Grove Gardens, Richv...
# 204  Albion Gardens, Beaumond Heights, Humbergate, ...
# 205                                          Northwest
#
# [206 rows x 3 columns]

# %%
nb_df_combine.shape
# Out:
# (103, 3)
